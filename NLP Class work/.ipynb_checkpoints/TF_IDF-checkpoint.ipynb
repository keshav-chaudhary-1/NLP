# %%
#bagwords (convert document of words into vector of numbers)
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer()
documents ={"cat sat","cat sat on mat","cat sat on mat with hat"}
result = vectorizer.fit_transform(documents)
print(vectorizer.get_feature_names_out())
print(result.toarray())
# Out:
# ['cat' 'hat' 'mat' 'on' 'sat' 'with']
# [[1 0 0 0 1 0]
#  [1 1 1 1 1 1]
#  [1 0 1 1 1 0]]

# %%
#TF_IDF vectorizer 
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer()
documents ={"cat sat","cat sat on mat","cat sat on mat with hat"}
result = vectorizer.fit_transform(documents)
print(vectorizer.get_feature_names_out())
print(result.toarray())
# Out:
# ['cat' 'hat' 'mat' 'on' 'sat' 'with']
# [[0.70710678 0.         0.         0.         0.70710678 0.        ]
#  [0.30083189 0.50935267 0.38737583 0.38737583 0.30083189 0.50935267]
#  [0.43370786 0.         0.55847784 0.55847784 0.43370786 0.        ]]
